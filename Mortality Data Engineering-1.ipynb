# %% [markdown]
# # Import and Reading

# %%
import pandas as pd

# %%
df = pd.read_csv('T404.csv')
df
# Out:
#        Education  Month of Death Sex  AgeCode  Age  AgeCategory  \
# 0              4               1   M        1   62           38
# 1              2               1   M        1   17           29
# 2              4               1   M        1   35           33
# 3              3               1   M        1   30           32
# 4              1               1   M        1   68           39
# ...          ...             ...  ..      ...  ...          ...
# 72231          1              12   M        1   50           36
# 72232          3              12   F        1   64           38
# 72233          3              12   M        1   47           35
# 72234          3              12   M        1   64           38
# 72235          3              12   M        1   46           35
#
#       Marital Status  Manner of Death  Race  Occupation  ...  Condition12  \
# 0                  D              1.0     3         1.0  ...          NaN
# 1                  S              1.0     1        25.0  ...          NaN
# 2                  S              1.0     1         1.0  ...          NaN
# 3                  S              1.0     3        18.0  ...          NaN
# 4                  D              1.0     1         1.0  ...          NaN
# ...              ...              ...   ...         ...  ...          ...
# 72231              U              1.0     1        19.0  ...          NaN
# 72232              D              1.0     1        26.0  ...          NaN
# 72233              D              1.0     2        22.0  ...          NaN
# 72234              S              1.0     1        25.0  ...          NaN
# 72235              M              1.0     2        15.0  ...          NaN
#
#       Condition13 Condition14 Condition15 Condition16 Condition17 Condition18  \
# 0             NaN         NaN         NaN         NaN         NaN         NaN
# 1             NaN         NaN         NaN         NaN         NaN         NaN
# 2             NaN         NaN         NaN         NaN         NaN         NaN
# 3             NaN         NaN         NaN         NaN         NaN         NaN
# 4             NaN         NaN         NaN         NaN         NaN         NaN
# ...           ...         ...         ...         ...         ...         ...
# 72231         NaN         NaN         NaN         NaN         NaN         NaN
# 72232         NaN         NaN         NaN         NaN         NaN         NaN
# 72233         NaN         NaN         NaN         NaN         NaN         NaN
# 72234         NaN         NaN         NaN         NaN         NaN         NaN
# 72235         NaN         NaN         NaN         NaN         NaN         NaN
#
#       Condition19 Condition20  Year
# 0             NaN         NaN  2021
# 1             NaN         NaN  2021
# 2             NaN         NaN  2021
# 3             NaN         NaN  2021
# 4             NaN         NaN  2021
# ...           ...         ...   ...
# 72231         NaN         NaN  2021
# 72232         NaN         NaN  2021
# 72233         NaN         NaN  2021
# 72234         NaN         NaN  2021
# 72235         NaN         NaN  2021
#
# [72236 rows x 33 columns]

# %% [markdown]
# # We are DROPPING 2017 due to different code-keeping styles

# %%
df = df[(df['Year'] == 2020) | (df['Year'] == 2021)]
df
# Out:
#        Education  Month of Death Sex  AgeCode  Age  AgeCategory  \
# 0              4               1   M        1   62           38
# 1              2               1   M        1   17           29
# 2              4               1   M        1   35           33
# 3              3               1   M        1   30           32
# 4              1               1   M        1   68           39
# ...          ...             ...  ..      ...  ...          ...
# 72231          1              12   M        1   50           36
# 72232          3              12   F        1   64           38
# 72233          3              12   M        1   47           35
# 72234          3              12   M        1   64           38
# 72235          3              12   M        1   46           35
#
#       Marital Status  Manner of Death  Race  Occupation  ...  Condition12  \
# 0                  D              1.0     3         1.0  ...          NaN
# 1                  S              1.0     1        25.0  ...          NaN
# 2                  S              1.0     1         1.0  ...          NaN
# 3                  S              1.0     3        18.0  ...          NaN
# 4                  D              1.0     1         1.0  ...          NaN
# ...              ...              ...   ...         ...  ...          ...
# 72231              U              1.0     1        19.0  ...          NaN
# 72232              D              1.0     1        26.0  ...          NaN
# 72233              D              1.0     2        22.0  ...          NaN
# 72234              S              1.0     1        25.0  ...          NaN
# 72235              M              1.0     2        15.0  ...          NaN
#
#       Condition13 Condition14 Condition15 Condition16 Condition17 Condition18  \
# 0             NaN         NaN         NaN         NaN         NaN         NaN
# 1             NaN         NaN         NaN         NaN         NaN         NaN
# 2             NaN         NaN         NaN         NaN         NaN         NaN
# 3             NaN         NaN         NaN         NaN         NaN         NaN
# 4             NaN         NaN         NaN         NaN         NaN         NaN
# ...           ...         ...         ...         ...         ...         ...
# 72231         NaN         NaN         NaN         NaN         NaN         NaN
# 72232         NaN         NaN         NaN         NaN         NaN         NaN
# 72233         NaN         NaN         NaN         NaN         NaN         NaN
# 72234         NaN         NaN         NaN         NaN         NaN         NaN
# 72235         NaN         NaN         NaN         NaN         NaN         NaN
#
#       Condition19 Condition20  Year
# 0             NaN         NaN  2021
# 1             NaN         NaN  2021
# 2             NaN         NaN  2021
# 3             NaN         NaN  2021
# 4             NaN         NaN  2021
# ...           ...         ...   ...
# 72231         NaN         NaN  2021
# 72232         NaN         NaN  2021
# 72233         NaN         NaN  2021
# 72234         NaN         NaN  2021
# 72235         NaN         NaN  2021
#
# [72236 rows x 33 columns]

# %%
# Dictionary for education codes
education_mapping = {
    1.0 : '8th grade or less',
    2.0 : '9 - 12th grade, no diploma',
    3.0 : 'High school graduate or GED completed',
    4.0 : 'Some college credit, but no degree',
    5.0 : 'Associate degree',
    6.0 : 'Bachelors degree',
    7.0 : 'Masters degree',
    8.0 : 'Doctorate or professional degree',
    9.0 : 'Unknown'
}


df['Education'] = df['Education'].map(education_mapping)
df
# Out:
#                                    Education  Month of Death Sex  AgeCode  \
# 0         Some college credit, but no degree               1   M        1
# 1                 9 - 12th grade, no diploma               1   M        1
# 2         Some college credit, but no degree               1   M        1
# 3      High school graduate or GED completed               1   M        1
# 4                          8th grade or less               1   M        1
# ...                                      ...             ...  ..      ...
# 72231                      8th grade or less              12   M        1
# 72232  High school graduate or GED completed              12   F        1
# 72233  High school graduate or GED completed              12   M        1
# 72234  High school graduate or GED completed              12   M        1
# 72235  High school graduate or GED completed              12   M        1
#
#        Age  AgeCategory Marital Status  Manner of Death  Race  Occupation  \
# 0       62           38              D              1.0     3         1.0
# 1       17           29              S              1.0     1        25.0
# 2       35           33              S              1.0     1         1.0
# 3       30           32              S              1.0     3        18.0
# 4       68           39              D              1.0     1         1.0
# ...    ...          ...            ...              ...   ...         ...
# 72231   50           36              U              1.0     1        19.0
# 72232   64           38              D              1.0     1        26.0
# 72233   47           35              D              1.0     2        22.0
# 72234   64           38              S              1.0     1        25.0
# 72235   46           35              M              1.0     2        15.0
#
#        ...  Condition12 Condition13 Condition14 Condition15 Condition16  \
# 0      ...          NaN         NaN         NaN         NaN         NaN
# 1      ...          NaN         NaN         NaN         NaN         NaN
# 2      ...          NaN         NaN         NaN         NaN         NaN
# 3      ...          NaN         NaN         NaN         NaN         NaN
# 4      ...          NaN         NaN         NaN         NaN         NaN
# ...    ...          ...         ...         ...         ...         ...
# 72231  ...          NaN         NaN         NaN         NaN         NaN
# 72232  ...          NaN         NaN         NaN         NaN         NaN
# 72233  ...          NaN         NaN         NaN         NaN         NaN
# 72234  ...          NaN         NaN         NaN         NaN         NaN
# 72235  ...          NaN         NaN         NaN         NaN         NaN
#
#       Condition17 Condition18 Condition19 Condition20  Year
# 0             NaN         NaN         NaN         NaN  2021
# 1             NaN         NaN         NaN         NaN  2021
# 2             NaN         NaN         NaN         NaN  2021
# 3             NaN         NaN         NaN         NaN  2021
# 4             NaN         NaN         NaN         NaN  2021
# ...           ...         ...         ...         ...   ...
# 72231         NaN         NaN         NaN         NaN  2021
# 72232         NaN         NaN         NaN         NaN  2021
# 72233         NaN         NaN         NaN         NaN  2021
# 72234         NaN         NaN         NaN         NaN  2021
# 72235         NaN         NaN         NaN         NaN  2021
#
# [72236 rows x 33 columns]

# %%
# Dictionary for month codes
month_mapping = {
    1 : 'January',
    2 : 'February',
    3 : 'March',
    4 : 'April',
    5 : 'May',
    6 : 'June',
    7 : 'July',
    8 : 'August',
    9 : 'September',
    10 : 'October',
    11 : 'November',
    12 : 'December'
}


df['Month of Death'] = df['Month of Death'].map(month_mapping)
df
# Out:
#                                    Education Month of Death Sex  AgeCode  Age  \
# 0         Some college credit, but no degree        January   M        1   62
# 1                 9 - 12th grade, no diploma        January   M        1   17
# 2         Some college credit, but no degree        January   M        1   35
# 3      High school graduate or GED completed        January   M        1   30
# 4                          8th grade or less        January   M        1   68
# ...                                      ...            ...  ..      ...  ...
# 72231                      8th grade or less       December   M        1   50
# 72232  High school graduate or GED completed       December   F        1   64
# 72233  High school graduate or GED completed       December   M        1   47
# 72234  High school graduate or GED completed       December   M        1   64
# 72235  High school graduate or GED completed       December   M        1   46
#
#        AgeCategory Marital Status  Manner of Death  Race  Occupation  ...  \
# 0               38              D              1.0     3         1.0  ...
# 1               29              S              1.0     1        25.0  ...
# 2               33              S              1.0     1         1.0  ...
# 3               32              S              1.0     3        18.0  ...
# 4               39              D              1.0     1         1.0  ...
# ...            ...            ...              ...   ...         ...  ...
# 72231           36              U              1.0     1        19.0  ...
# 72232           38              D              1.0     1        26.0  ...
# 72233           35              D              1.0     2        22.0  ...
# 72234           38              S              1.0     1        25.0  ...
# 72235           35              M              1.0     2        15.0  ...
#
#        Condition12 Condition13 Condition14 Condition15 Condition16  \
# 0              NaN         NaN         NaN         NaN         NaN
# 1              NaN         NaN         NaN         NaN         NaN
# 2              NaN         NaN         NaN         NaN         NaN
# 3              NaN         NaN         NaN         NaN         NaN
# 4              NaN         NaN         NaN         NaN         NaN
# ...            ...         ...         ...         ...         ...
# 72231          NaN         NaN         NaN         NaN         NaN
# 72232          NaN         NaN         NaN         NaN         NaN
# 72233          NaN         NaN         NaN         NaN         NaN
# 72234          NaN         NaN         NaN         NaN         NaN
# 72235          NaN         NaN         NaN         NaN         NaN
#
#       Condition17 Condition18 Condition19 Condition20  Year
# 0             NaN         NaN         NaN         NaN  2021
# 1             NaN         NaN         NaN         NaN  2021
# 2             NaN         NaN         NaN         NaN  2021
# 3             NaN         NaN         NaN         NaN  2021
# 4             NaN         NaN         NaN         NaN  2021
# ...           ...         ...         ...         ...   ...
# 72231         NaN         NaN         NaN         NaN  2021
# 72232         NaN         NaN         NaN         NaN  2021
# 72233         NaN         NaN         NaN         NaN  2021
# 72234         NaN         NaN         NaN         NaN  2021
# 72235         NaN         NaN         NaN         NaN  2021
#
# [72236 rows x 33 columns]

# %%
# Dictionary for age codes
age_mapping = {
    23: '1 year',
    24: '2 years',
    25: '3 years',
    26: '4 years',
    27: '5 - 9 years',
    28: '10 - 14 years',
    29: '15 - 19 years',
    30: '20 - 24 years',
    31: '25 - 29 years',
    32: '30 - 34 years',
    33: '35 - 39 years',
    34: '40 - 44 years',
    35: '45 - 49 years',
    36: '50 - 54 years',
    37: '55 - 59 years',
    38: '60 - 64 years',
    39: '65 - 69 years',
    40: '70 - 74 years',
    41: '75 - 79 years',
    42: '80 - 84 years',
    43: '85 - 89 years',
    44: '90 - 94 years',
    45: '95 - 99 years',
    46: '100 - 104 years',
    47: '105 - 109 years'
}

df['AgeCategory'] = df['AgeCategory'].map(age_mapping)
df
# Out:
#                                    Education Month of Death Sex  AgeCode  Age  \
# 0         Some college credit, but no degree        January   M        1   62
# 1                 9 - 12th grade, no diploma        January   M        1   17
# 2         Some college credit, but no degree        January   M        1   35
# 3      High school graduate or GED completed        January   M        1   30
# 4                          8th grade or less        January   M        1   68
# ...                                      ...            ...  ..      ...  ...
# 72231                      8th grade or less       December   M        1   50
# 72232  High school graduate or GED completed       December   F        1   64
# 72233  High school graduate or GED completed       December   M        1   47
# 72234  High school graduate or GED completed       December   M        1   64
# 72235  High school graduate or GED completed       December   M        1   46
#
#          AgeCategory Marital Status  Manner of Death  Race  Occupation  ...  \
# 0      60 - 64 years              D              1.0     3         1.0  ...
# 1      15 - 19 years              S              1.0     1        25.0  ...
# 2      35 - 39 years              S              1.0     1         1.0  ...
# 3      30 - 34 years              S              1.0     3        18.0  ...
# 4      65 - 69 years              D              1.0     1         1.0  ...
# ...              ...            ...              ...   ...         ...  ...
# 72231  50 - 54 years              U              1.0     1        19.0  ...
# 72232  60 - 64 years              D              1.0     1        26.0  ...
# 72233  45 - 49 years              D              1.0     2        22.0  ...
# 72234  60 - 64 years              S              1.0     1        25.0  ...
# 72235  45 - 49 years              M              1.0     2        15.0  ...
#
#        Condition12 Condition13 Condition14 Condition15 Condition16  \
# 0              NaN         NaN         NaN         NaN         NaN
# 1              NaN         NaN         NaN         NaN         NaN
# 2              NaN         NaN         NaN         NaN         NaN
# 3              NaN         NaN         NaN         NaN         NaN
# 4              NaN         NaN         NaN         NaN         NaN
# ...            ...         ...         ...         ...         ...
# 72231          NaN         NaN         NaN         NaN         NaN
# 72232          NaN         NaN         NaN         NaN         NaN
# 72233          NaN         NaN         NaN         NaN         NaN
# 72234          NaN         NaN         NaN         NaN         NaN
# 72235          NaN         NaN         NaN         NaN         NaN
#
#       Condition17 Condition18 Condition19 Condition20  Year
# 0             NaN         NaN         NaN         NaN  2021
# 1             NaN         NaN         NaN         NaN  2021
# 2             NaN         NaN         NaN         NaN  2021
# 3             NaN         NaN         NaN         NaN  2021
# 4             NaN         NaN         NaN         NaN  2021
# ...           ...         ...         ...         ...   ...
# 72231         NaN         NaN         NaN         NaN  2021
# 72232         NaN         NaN         NaN         NaN  2021
# 72233         NaN         NaN         NaN         NaN  2021
# 72234         NaN         NaN         NaN         NaN  2021
# 72235         NaN         NaN         NaN         NaN  2021
#
# [72236 rows x 33 columns]

# %%
marital_mapping = {
    'S':'Never married, single',
    'M':'Married',
    'W':'Widowed',
    'D':'Divorced',
    'U':'Marital Status unknown'
}

df['Marital Status'] = df['Marital Status'].map(marital_mapping)
df
# Out:
#                                    Education Month of Death Sex  AgeCode  Age  \
# 0         Some college credit, but no degree        January   M        1   62
# 1                 9 - 12th grade, no diploma        January   M        1   17
# 2         Some college credit, but no degree        January   M        1   35
# 3      High school graduate or GED completed        January   M        1   30
# 4                          8th grade or less        January   M        1   68
# ...                                      ...            ...  ..      ...  ...
# 72231                      8th grade or less       December   M        1   50
# 72232  High school graduate or GED completed       December   F        1   64
# 72233  High school graduate or GED completed       December   M        1   47
# 72234  High school graduate or GED completed       December   M        1   64
# 72235  High school graduate or GED completed       December   M        1   46
#
#          AgeCategory          Marital Status  Manner of Death  Race  \
# 0      60 - 64 years                Divorced              1.0     3
# 1      15 - 19 years   Never married, single              1.0     1
# 2      35 - 39 years   Never married, single              1.0     1
# 3      30 - 34 years   Never married, single              1.0     3
# 4      65 - 69 years                Divorced              1.0     1
# ...              ...                     ...              ...   ...
# 72231  50 - 54 years  Marital Status unknown              1.0     1
# 72232  60 - 64 years                Divorced              1.0     1
# 72233  45 - 49 years                Divorced              1.0     2
# 72234  60 - 64 years   Never married, single              1.0     1
# 72235  45 - 49 years                 Married              1.0     2
#
#        Occupation  ...  Condition12 Condition13 Condition14 Condition15  \
# 0             1.0  ...          NaN         NaN         NaN         NaN
# 1            25.0  ...          NaN         NaN         NaN         NaN
# 2             1.0  ...          NaN         NaN         NaN         NaN
# 3            18.0  ...          NaN         NaN         NaN         NaN
# 4             1.0  ...          NaN         NaN         NaN         NaN
# ...           ...  ...          ...         ...         ...         ...
# 72231        19.0  ...          NaN         NaN         NaN         NaN
# 72232        26.0  ...          NaN         NaN         NaN         NaN
# 72233        22.0  ...          NaN         NaN         NaN         NaN
# 72234        25.0  ...          NaN         NaN         NaN         NaN
# 72235        15.0  ...          NaN         NaN         NaN         NaN
#
#       Condition16 Condition17 Condition18 Condition19 Condition20  Year
# 0             NaN         NaN         NaN         NaN         NaN  2021
# 1             NaN         NaN         NaN         NaN         NaN  2021
# 2             NaN         NaN         NaN         NaN         NaN  2021
# 3             NaN         NaN         NaN         NaN         NaN  2021
# 4             NaN         NaN         NaN         NaN         NaN  2021
# ...           ...         ...         ...         ...         ...   ...
# 72231         NaN         NaN         NaN         NaN         NaN  2021
# 72232         NaN         NaN         NaN         NaN         NaN  2021
# 72233         NaN         NaN         NaN         NaN         NaN  2021
# 72234         NaN         NaN         NaN         NaN         NaN  2021
# 72235         NaN         NaN         NaN         NaN         NaN  2021
#
# [72236 rows x 33 columns]

# %%
manner_of_death_mapping = {
    1.0: 'Accident',
    2.0: 'Suicide',
    3.0: 'Homicide',
    4.0: 'Pending investigation',
    5.0: 'Could not determine',
    6.0: 'Self-Inflicted',
    7.0: 'Natural'
}

df['Manner of Death'] = df['Manner of Death'].map(manner_of_death_mapping)
df
# Out:
#                                    Education Month of Death Sex  AgeCode  Age  \
# 0         Some college credit, but no degree        January   M        1   62
# 1                 9 - 12th grade, no diploma        January   M        1   17
# 2         Some college credit, but no degree        January   M        1   35
# 3      High school graduate or GED completed        January   M        1   30
# 4                          8th grade or less        January   M        1   68
# ...                                      ...            ...  ..      ...  ...
# 72231                      8th grade or less       December   M        1   50
# 72232  High school graduate or GED completed       December   F        1   64
# 72233  High school graduate or GED completed       December   M        1   47
# 72234  High school graduate or GED completed       December   M        1   64
# 72235  High school graduate or GED completed       December   M        1   46
#
#          AgeCategory          Marital Status Manner of Death  Race  \
# 0      60 - 64 years                Divorced        Accident     3
# 1      15 - 19 years   Never married, single        Accident     1
# 2      35 - 39 years   Never married, single        Accident     1
# 3      30 - 34 years   Never married, single        Accident     3
# 4      65 - 69 years                Divorced        Accident     1
# ...              ...                     ...             ...   ...
# 72231  50 - 54 years  Marital Status unknown        Accident     1
# 72232  60 - 64 years                Divorced        Accident     1
# 72233  45 - 49 years                Divorced        Accident     2
# 72234  60 - 64 years   Never married, single        Accident     1
# 72235  45 - 49 years                 Married        Accident     2
#
#        Occupation  ...  Condition12 Condition13 Condition14 Condition15  \
# 0             1.0  ...          NaN         NaN         NaN         NaN
# 1            25.0  ...          NaN         NaN         NaN         NaN
# 2             1.0  ...          NaN         NaN         NaN         NaN
# 3            18.0  ...          NaN         NaN         NaN         NaN
# 4             1.0  ...          NaN         NaN         NaN         NaN
# ...           ...  ...          ...         ...         ...         ...
# 72231        19.0  ...          NaN         NaN         NaN         NaN
# 72232        26.0  ...          NaN         NaN         NaN         NaN
# 72233        22.0  ...          NaN         NaN         NaN         NaN
# 72234        25.0  ...          NaN         NaN         NaN         NaN
# 72235        15.0  ...          NaN         NaN         NaN         NaN
#
#       Condition16 Condition17 Condition18 Condition19 Condition20  Year
# 0             NaN         NaN         NaN         NaN         NaN  2021
# 1             NaN         NaN         NaN         NaN         NaN  2021
# 2             NaN         NaN         NaN         NaN         NaN  2021
# 3             NaN         NaN         NaN         NaN         NaN  2021
# 4             NaN         NaN         NaN         NaN         NaN  2021
# ...           ...         ...         ...         ...         ...   ...
# 72231         NaN         NaN         NaN         NaN         NaN  2021
# 72232         NaN         NaN         NaN         NaN         NaN  2021
# 72233         NaN         NaN         NaN         NaN         NaN  2021
# 72234         NaN         NaN         NaN         NaN         NaN  2021
# 72235         NaN         NaN         NaN         NaN         NaN  2021
#
# [72236 rows x 33 columns]

# %%
# Dictionary for ethnicity codes
race_mapping = {
    1: 'White',
    2: 'Black',
    3: 'American Indian or Alaskan Native (AIAN)',
    4: 'Asian Indian',
    5: 'Chinese',
    6: 'Filipino',
    7: 'Japanese',
    8: 'Korean',
    9: 'Vietnamese',
    10: 'Other or Multiple Asian',
    11: 'Hawaiian',
    12: 'Guamanian',
    13: 'Samoan',
    14: 'Other or Multiple Pacific Islander',
    15: 'Black and White',
    16: 'Black and AIAN',
    17: 'Black and Asian',
    18: 'Black and Native Hawaiian or Other Pacific Islander (NHOPI)',
    19: 'AIAN and White',
    20: 'AIAN and Asian',
    21: 'AIAN and NHOPI',
    22: 'Asian and White',
    23: 'Asian and NHOPI',
    24: 'NHOPI and White',
    25: 'Black, AIAN and White',
    26: 'Black, AIAN and Asian',
    27: 'Black, AIAN and NHOPI',
    28: 'Black, Asian and White',
    29: 'Black, Asian and NHOPI',
    30: 'Black, NHOPI and White',
    31: 'AIAN, Asian and White',
    32: 'AIAN, NHOPI and White',
    33: 'AIAN, Asian and NHOPI',
    34: 'Asian, NHOPI and White',
    35: 'Black, AIAN, Asian and White',
    36: 'Black, AIAN, Asian and NHOPI',
    37: 'Black, AIAN, NHOPI and White',
    38: 'Black, Asian, NHOPI and White',
    39: 'AIAN, Asian, NHOPI and White',
    40: 'Black, AIAN, Asian, NHOPI and White'
}

df['Race'] = df['Race'].map(race_mapping)
df
# Out:
#                                    Education Month of Death Sex  AgeCode  Age  \
# 0         Some college credit, but no degree        January   M        1   62
# 1                 9 - 12th grade, no diploma        January   M        1   17
# 2         Some college credit, but no degree        January   M        1   35
# 3      High school graduate or GED completed        January   M        1   30
# 4                          8th grade or less        January   M        1   68
# ...                                      ...            ...  ..      ...  ...
# 72231                      8th grade or less       December   M        1   50
# 72232  High school graduate or GED completed       December   F        1   64
# 72233  High school graduate or GED completed       December   M        1   47
# 72234  High school graduate or GED completed       December   M        1   64
# 72235  High school graduate or GED completed       December   M        1   46
#
#          AgeCategory          Marital Status Manner of Death  \
# 0      60 - 64 years                Divorced        Accident
# 1      15 - 19 years   Never married, single        Accident
# 2      35 - 39 years   Never married, single        Accident
# 3      30 - 34 years   Never married, single        Accident
# 4      65 - 69 years                Divorced        Accident
# ...              ...                     ...             ...
# 72231  50 - 54 years  Marital Status unknown        Accident
# 72232  60 - 64 years                Divorced        Accident
# 72233  45 - 49 years                Divorced        Accident
# 72234  60 - 64 years   Never married, single        Accident
# 72235  45 - 49 years                 Married        Accident
#
#                                            Race  Occupation  ...  Condition12  \
# 0      American Indian or Alaskan Native (AIAN)         1.0  ...          NaN
# 1                                         White        25.0  ...          NaN
# 2                                         White         1.0  ...          NaN
# 3      American Indian or Alaskan Native (AIAN)        18.0  ...          NaN
# 4                                         White         1.0  ...          NaN
# ...                                         ...         ...  ...          ...
# 72231                                     White        19.0  ...          NaN
# 72232                                     White        26.0  ...          NaN
# 72233                                     Black        22.0  ...          NaN
# 72234                                     White        25.0  ...          NaN
# 72235                                     Black        15.0  ...          NaN
#
#       Condition13 Condition14 Condition15 Condition16 Condition17 Condition18  \
# 0             NaN         NaN         NaN         NaN         NaN         NaN
# 1             NaN         NaN         NaN         NaN         NaN         NaN
# 2             NaN         NaN         NaN         NaN         NaN         NaN
# 3             NaN         NaN         NaN         NaN         NaN         NaN
# 4             NaN         NaN         NaN         NaN         NaN         NaN
# ...           ...         ...         ...         ...         ...         ...
# 72231         NaN         NaN         NaN         NaN         NaN         NaN
# 72232         NaN         NaN         NaN         NaN         NaN         NaN
# 72233         NaN         NaN         NaN         NaN         NaN         NaN
# 72234         NaN         NaN         NaN         NaN         NaN         NaN
# 72235         NaN         NaN         NaN         NaN         NaN         NaN
#
#       Condition19 Condition20  Year
# 0             NaN         NaN  2021
# 1             NaN         NaN  2021
# 2             NaN         NaN  2021
# 3             NaN         NaN  2021
# 4             NaN         NaN  2021
# ...           ...         ...   ...
# 72231         NaN         NaN  2021
# 72232         NaN         NaN  2021
# 72233         NaN         NaN  2021
# 72234         NaN         NaN  2021
# 72235         NaN         NaN  2021
#
# [72236 rows x 33 columns]

# %%
occupation_mapping = {
    1.0: 'Management Occupations',
    2.0: 'Business & Financial Operations Occupations',
    3.0: 'Computer & Mathematical Occupations',
    4.0: 'Architecture & Engineering Occupations',
    5.0: 'Life, Physical, & Social Science Occupations',
    6.0: 'Community & Social Services Occupations',
    7.0: 'Legal Occupations',
    8.0: 'Education, Training, & Library Occupations',
    9.0: 'Arts, Design, Entertainment, Sports, & Media Occupations',
    10.0: 'Healthcare Practitioners & Technical Occupations',
    11.0: 'Healthcare Support Occupations',
    12.0: 'Protective Service Occupations',
    13.0: 'Food Preparation & Serving Related Occupations',
    14.0: 'Building & Grounds Cleaning & Maintenance Occupations',
    15.0: 'Personal Care & Service Occupations',
    16.0: 'Sales & Related Occupations',
    17.0: 'Office & Administrative Support Occupations',
    18.0: 'Farming, Fishing, & Forestry Occupations',
    19.0: 'Construction & Extraction Occupations',
    20.0: 'Installation, Maintenance, & Repair Occupations',
    21.0: 'Production Occupations',
    22.0: 'Transportation & Material Moving Occupations',
    24.0: 'Military',
    25.0: 'Other, Misc (exc Housewife)',
    26.0: 'Other, Housewife'
}

df['Occupation'] = df['Occupation'].map(occupation_mapping)
df
# Out:
#                                    Education Month of Death Sex  AgeCode  Age  \
# 0         Some college credit, but no degree        January   M        1   62
# 1                 9 - 12th grade, no diploma        January   M        1   17
# 2         Some college credit, but no degree        January   M        1   35
# 3      High school graduate or GED completed        January   M        1   30
# 4                          8th grade or less        January   M        1   68
# ...                                      ...            ...  ..      ...  ...
# 72231                      8th grade or less       December   M        1   50
# 72232  High school graduate or GED completed       December   F        1   64
# 72233  High school graduate or GED completed       December   M        1   47
# 72234  High school graduate or GED completed       December   M        1   64
# 72235  High school graduate or GED completed       December   M        1   46
#
#          AgeCategory          Marital Status Manner of Death  \
# 0      60 - 64 years                Divorced        Accident
# 1      15 - 19 years   Never married, single        Accident
# 2      35 - 39 years   Never married, single        Accident
# 3      30 - 34 years   Never married, single        Accident
# 4      65 - 69 years                Divorced        Accident
# ...              ...                     ...             ...
# 72231  50 - 54 years  Marital Status unknown        Accident
# 72232  60 - 64 years                Divorced        Accident
# 72233  45 - 49 years                Divorced        Accident
# 72234  60 - 64 years   Never married, single        Accident
# 72235  45 - 49 years                 Married        Accident
#
#                                            Race  \
# 0      American Indian or Alaskan Native (AIAN)
# 1                                         White
# 2                                         White
# 3      American Indian or Alaskan Native (AIAN)
# 4                                         White
# ...                                         ...
# 72231                                     White
# 72232                                     White
# 72233                                     Black
# 72234                                     White
# 72235                                     Black
#
#                                          Occupation  ...  Condition12  \
# 0                            Management Occupations  ...          NaN
# 1                       Other, Misc (exc Housewife)  ...          NaN
# 2                            Management Occupations  ...          NaN
# 3          Farming, Fishing, & Forestry Occupations  ...          NaN
# 4                            Management Occupations  ...          NaN
# ...                                             ...  ...          ...
# 72231         Construction & Extraction Occupations  ...          NaN
# 72232                              Other, Housewife  ...          NaN
# 72233  Transportation & Material Moving Occupations  ...          NaN
# 72234                   Other, Misc (exc Housewife)  ...          NaN
# 72235           Personal Care & Service Occupations  ...          NaN
#
#       Condition13 Condition14 Condition15 Condition16 Condition17 Condition18  \
# 0             NaN         NaN         NaN         NaN         NaN         NaN
# 1             NaN         NaN         NaN         NaN         NaN         NaN
# 2             NaN         NaN         NaN         NaN         NaN         NaN
# 3             NaN         NaN         NaN         NaN         NaN         NaN
# 4             NaN         NaN         NaN         NaN         NaN         NaN
# ...           ...         ...         ...         ...         ...         ...
# 72231         NaN         NaN         NaN         NaN         NaN         NaN
# 72232         NaN         NaN         NaN         NaN         NaN         NaN
# 72233         NaN         NaN         NaN         NaN         NaN         NaN
# 72234         NaN         NaN         NaN         NaN         NaN         NaN
# 72235         NaN         NaN         NaN         NaN         NaN         NaN
#
#       Condition19 Condition20  Year
# 0             NaN         NaN  2021
# 1             NaN         NaN  2021
# 2             NaN         NaN  2021
# 3             NaN         NaN  2021
# 4             NaN         NaN  2021
# ...           ...         ...   ...
# 72231         NaN         NaN  2021
# 72232         NaN         NaN  2021
# 72233         NaN         NaN  2021
# 72234         NaN         NaN  2021
# 72235         NaN         NaN  2021
#
# [72236 rows x 33 columns]

# %%
death_mapping = {
    420:'Accidental Drug Poisoning',
    425:'Suicide Drug Poisoning',
    443:'Undetermined Drug Poisoning'
}

df['Death'] = df['Death'].map(death_mapping)
df
# Out:
#                                    Education Month of Death Sex  AgeCode  Age  \
# 0         Some college credit, but no degree        January   M        1   62
# 1                 9 - 12th grade, no diploma        January   M        1   17
# 2         Some college credit, but no degree        January   M        1   35
# 3      High school graduate or GED completed        January   M        1   30
# 4                          8th grade or less        January   M        1   68
# ...                                      ...            ...  ..      ...  ...
# 72231                      8th grade or less       December   M        1   50
# 72232  High school graduate or GED completed       December   F        1   64
# 72233  High school graduate or GED completed       December   M        1   47
# 72234  High school graduate or GED completed       December   M        1   64
# 72235  High school graduate or GED completed       December   M        1   46
#
#          AgeCategory          Marital Status Manner of Death  \
# 0      60 - 64 years                Divorced        Accident
# 1      15 - 19 years   Never married, single        Accident
# 2      35 - 39 years   Never married, single        Accident
# 3      30 - 34 years   Never married, single        Accident
# 4      65 - 69 years                Divorced        Accident
# ...              ...                     ...             ...
# 72231  50 - 54 years  Marital Status unknown        Accident
# 72232  60 - 64 years                Divorced        Accident
# 72233  45 - 49 years                Divorced        Accident
# 72234  60 - 64 years   Never married, single        Accident
# 72235  45 - 49 years                 Married        Accident
#
#                                            Race  \
# 0      American Indian or Alaskan Native (AIAN)
# 1                                         White
# 2                                         White
# 3      American Indian or Alaskan Native (AIAN)
# 4                                         White
# ...                                         ...
# 72231                                     White
# 72232                                     White
# 72233                                     Black
# 72234                                     White
# 72235                                     Black
#
#                                          Occupation  ... Condition12  \
# 0                            Management Occupations  ...         NaN
# 1                       Other, Misc (exc Housewife)  ...         NaN
# 2                            Management Occupations  ...         NaN
# 3          Farming, Fishing, & Forestry Occupations  ...         NaN
# 4                            Management Occupations  ...         NaN
# ...                                             ...  ...         ...
# 72231         Construction & Extraction Occupations  ...         NaN
# 72232                              Other, Housewife  ...         NaN
# 72233  Transportation & Material Moving Occupations  ...         NaN
# 72234                   Other, Misc (exc Housewife)  ...         NaN
# 72235           Personal Care & Service Occupations  ...         NaN
#
#       Condition13 Condition14 Condition15 Condition16 Condition17 Condition18  \
# 0             NaN         NaN         NaN         NaN         NaN         NaN
# 1             NaN         NaN         NaN         NaN         NaN         NaN
# 2             NaN         NaN         NaN         NaN         NaN         NaN
# 3             NaN         NaN         NaN         NaN         NaN         NaN
# 4             NaN         NaN         NaN         NaN         NaN         NaN
# ...           ...         ...         ...         ...         ...         ...
# 72231         NaN         NaN         NaN         NaN         NaN         NaN
# 72232         NaN         NaN         NaN         NaN         NaN         NaN
# 72233         NaN         NaN         NaN         NaN         NaN         NaN
# 72234         NaN         NaN         NaN         NaN         NaN         NaN
# 72235         NaN         NaN         NaN         NaN         NaN         NaN
#
#       Condition19 Condition20  Year
# 0             NaN         NaN  2021
# 1             NaN         NaN  2021
# 2             NaN         NaN  2021
# 3             NaN         NaN  2021
# 4             NaN         NaN  2021
# ...           ...         ...   ...
# 72231         NaN         NaN  2021
# 72232         NaN         NaN  2021
# 72233         NaN         NaN  2021
# 72234         NaN         NaN  2021
# 72235         NaN         NaN  2021
#
# [72236 rows x 33 columns]

# %%
#Use for value counts

df['Marital Status'].value_counts()
# Out:
# Never married, single     43313
# Divorced                  14199
# Married                   10907
# Widowed                    2178
# Marital Status unknown     1639
# Name: Marital Status, dtype: int64

# %%
df.to_csv('Updated.csv', index=False)
